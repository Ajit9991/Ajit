# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajit9991/Ajit/blob/master/ML_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **32513 – Machine Learning**
#
# **Assignment 3 – Plan for Solving a Domain Problem**
#
#
# **Topic – Solid System Solution For Healthcare domain****
#
# **Ajit Pokharkar**
#
# **Student Id- 12980746**
#
# Assignment available at
#
# Video pitch available at [https://www.youtube.com/watch?v=0R_EFajCdp8]
#
#
#
#
#
#
# **Table of Contents**
#
# 1. Aim
# 2. Background
# 3. Objectives & Expected Outcome
# 4. Research Project
# 5. Duration of the project development
# 6. Personnel
# 7. Budget
#
#  Bibliography
#
#
#  **1. Aim**
#
# The aim of this project is to provide develop a solution to the healthcare sector which will help for the patient as well as hospitals to track the real-time information of patients also helps to find the pattern of disease and give the service to the patients accordingly which helps hospitals to build a relationship with patients.
#
# **2. Background**
#
# **2.1 Introduction**
#
# In this sector, all information stored in the digital format all over the place. This information includes the details of patients in the large amount, which is increasing day by day and that makes complexity to analyze the data if there is a traditional technology. Furthermore, the healthcare sector facing the biggest challenge is provide a quality of service with affordable charges. That's the reason, healthcare domain needs data mining to explore the data and find the pattern to make a decision about patients treatment. Data mining mechanisms are required to analyze the complex data and improve the process of the management and patient. Data mining solve the problem of identifying the disease of the patients and assist with the treatment accordingly and track the disease management (Ogundele, 2018). This management process helps to forecast the time of admission of the patient in clinic, accurate information management system, and prognosis of patients. In addition, it help to reduced a manual work, save lives, secure clinical data, reduce the charge of medical service and early detection of disease (Ionut, 2015).
#
# **2.2 Problems**
#
# The below mentioned is the problem of above proposal.
#
# i.	There is a privacy concern as data shared immensely during the process of data mining.
#
# ii.	Maintaining a quality of data to discover the fraud detection.
#
# iii.	Track the patient diagnosis data in order to provide the service.
#
# iv.	Data cleaning, storage, security, stewardship, query, reporting, visualization, updating, and sharing these are the common issues raised for big volume health data.
#
# These problems can be solved by developing new technique like using data mining and programming tools. The following discussion is objective and expected outcomes of this project.
#
# **3. Objectives & Expected Outcomes**
#
# **3.1 Objectives**
#
# The key idea is to build a system solution to solve healthcare problems by discovering the different technique of Machine Learning. The below mentioned are the essential objectives of this project.
#
# i.	Digital service for patients.
#
# ii.	Maintain the patient personal details and their disease information.
#
# iii.	Recommendation for treatment on the basis of patients test data.
#
# iv.	Reduced the manual work.
#
# v.	Design the data model to provide accurate results.
#
#
# **3.2 Expected Outcomes**
#
# Healthcare sector contains the rich data which is drastically changed on a daily basis. This project will help the health industry to perform smooth daily operations and build a relationship with patients. This project improves the quality of health service and effectively deal with the patients. The purpose of this project is to predict the different disease along with that provide the assistance to doctor to make a decision in clinical care. The below mentioned is the expected outcomes of this project after deployment:
#
# i.	automatically retrieve the patient information like number of times patient visit to hospital, what kind of disease patient have.
#
# ii.	Doctor will get suggestions for treatment.
#
# iii.	Hospital can easily make reports for various disease like how many patient have diabetes, cancer, heart stroke etc.
#
# iv.	Also look after the symptoms and treatment effects to find the effective way to deal with certain disease.
#
# v.	This system also help hospital to manage the staff schedule according to patients health.
#
# vi.	It helps to provide early prevention for disease also early discovery of disease.
#
# vii.	It will help to reduce human error.
#
#
#
# **4. Research Project**
#
#
# **4.1 Significance**
#
# In the above section 3 we have discussed the importance of this project, besides that there are other sections of this project which explores the how crucial this project is. The purpose of this project is computerized the process of patients profile and their various test report and many more information to find the pattern of disease and their impacts. This automate process help to provide cost-effective treatment to the patients also help to predict the disease. This project gives suggestions to doctor's to make a decision in clinical care and reduce human error. As a result, the health industry will be more organized and will reduced the time of manual work and staff will be more careful to look after the patients.
#
# This project significantly improves the service quality as we are going to use machine learning and different predictive tools to discover the common patterns and find the insights of the patient health data. The data mining helps to identify the relation between the instances and their occurrences which will help to choose the right procedure for treatment. This significance ensures the quality of service which helps health organisation to build their reputation, sets the standard and make them financially strong. Furthermore, this system solution helps doctors and staff to eliminate the error rate. As this project provides high -quality service and ensures the privacy of patient data which help to develop the relationship with patients.
#
# **4.2 Innovation behind the proposed project**
#
# This project has developed a new way to handle the patient historical and real-time data which help the health sector in many different ways. Furthermore, it helps the industry to perform smooth operations. The predictive analysis is one of the concepts of machine learning have been used to implement this project. The predictive analysis includes the various technique to analyze the historical and real-time data to make a forecast. There is a number of health industries which still refers to the traditional methods to maintain the patient log. This project innovation will automate the process for the health sector, it will assist the staff to look after the serious patients and manage everything within the time. Moreover,  system will identify the pattern in disease by using patient data which helps doctor's for treatment also patient data help to discover the knowledge of different disease and their relationship and their causes, it wouldn't be possible without machine learning. This project provide the solution to healthcare sector to identify a new trends, which support's to make decision in health treatment. In addition, this project provide the precise result and indentify the risk which helps doctor to converse with the patient in advance.
#
#
# **4.3 Action Plan**
#
# As we have discussed in the above section about the concept that we have used to implement this project. The action plan has divided into four stages which are explained in details in the below section.
#
# **4.3.1 Acquire patient historical and current data**
#
# Firstly, acquire the historical data of patients according to the requirement of this project. This step is very essential to begin the project. After the acquisition of the data, needs to be stored in a clean format which will help to identify the relationship between variables to solve the problems. If we save the data in the .csv file, it will be easier to perform  the data pre-processing operations on a train and test dataset. In this stage, the required operation is data extraction from various sources and transformation of the raw data which is handled by Data Analyst.
#
# **4.3.2 Modelling**
#
# The above stage helps to achieve higher accuracy results using a different data model. First of all, we need to do data pre-processing to develop the model. We have used the Python tool to perform all analytics operations using several data mining technique. In this process, the data analyst will help to identify the most suitable variables and appropriate constraint to design data model which work very effectively. This model builds to predict the new trend of the disease and give the best possible solution to the treatment on the basis of historical data by using Random Forest. This technique is an ensemble learning method and very effective to accomplish the regression and classification tasks. After applying the regression technique, trained and testing dataset will be ready to predict the treatment solution and the severity of the disease. These outcomes will be stored in .csv format which can easily accessible to management to review. This task handle by the data scientist and software developer.
#
#
# **4.3.3 Deployment**
#
# After the modelling stage, the next phase of this project is deployment. Before the deployment, the project goes through different types of testing. The main part of the testing is alpha and beta testing. In this context, the product owner has selected different health organisation to check the system functionality are working properly or not. This process called beta testing of the latest version of the project. This software makes available to limited users by providing credentials, so it will be easier for the development team to understand the performance of the system and functionality of the system are working properly with the help of doctors. This process helps to identify the defects to fix as soon as possible. During this process, company needs to make user manual or tutorials to educate the users to use the application. After all the back and forth process software gets ready to deploy. The deployment will be handled by software developer and QA engineer.
#
#
# **4.3.4 Maintenance**
#
# The final stage of this project is maintenance which is get done under the observation of financial team and product owner. There are certain legitimate obligations are applied to the project according to the companies norms, in order to ensure the patients for data privacy and security. The Business Analyst help to design the plan to execute the project, so the BA decides the next release of this product. The maintenance includes the expenses of whole project like hardware, software expenses, salaries, and duration of the project.
#
# **5. Duration of the project development**
#
# This section will gives the details of estimated time for project completion with  the Gantt chart presentation.
#
# **5.1  Estimate time for Action Plan**
#
# This project required one year time frame to implement. The below mentioned is the breakdown structure of the time.
#
# a.	Acquire patient historical and current data- 2 months
# 1.	First acquire the historical patient data - 12 days
# 2.	Second acquire the real-time data - 8 days
# 3.	Data cleaning and transformation - 40 days
#
# b.	Modeling - 5 months
# 1.	identify the requirement - 10 days
# 2.	design the plan for modeling - 30 days
# 3.	Implement the model - 82 days
# 4.	Testing of the model - 20 days
# 5.	Bug Fixing -10 days
#
# c.	Deployment- 4 months
# 1.	Launch the application for selected area - 10 days
# 2.	Tutorials for users - 10 days
# 3.	Beta testing -  40 days
# 4.	Modification - 20 days
# 5.	Regression testing - 15 days
# 6.	Rectification - 15 days
# 7.	Deployment - 12 days
#
# d.	Maintenance- 1 Month
# 1.	Gathered all the requirement for the  project - 11 days
# 2.	Make a budget accordingly - 20 days
#
#
# **5.2 Gantt Chart**
#
# The below figure is the visual representation of the task duration in days, which is represented by the Gantt chart. The project duration is one year so we can assume, the project begins in the October 1, 2019 and finish on July 7, 2020. In the below Gantt chart, bars represent the required days to accomplish the task.
#     ![alt text](https://drive.google.com/uc?id=1WGxERYmh8ZbGcY73Uwrwdo3JPHJ_S8Qn)
#
#
#
#
#
#
# **6. Personnel**
#
# This personnel section gives the details of the number of employees and employers and their roles and responsibility for this project. Furthermore, it includes the stakeholders details of this project. The below mentioned table includes the internal and stakeholders details.
#
# ![alt text](https://drive.google.com/uc?id=1hkAuohtzJmtNbyVPqDxMZj11Kc20QTtx)
#
#
# 1.	The CEO of the company is accountable to begin with the project and have discussion with internal and external stakeholders to make a deal.
# 2.	The CTO of the company is looking after all the project technique things like project requirement, project plan, required hardware, software etc.
# 3.	The Product Owner is the responsible to look after the project progress.
# 4.	Business Analyst help to gathered the requirement from the external stakeholder and provide it to the team and design the use cases for the project.
# 5.	There is Data Analysts, who is responsible for data cleaning and transformation process and deliver the clean format data to Data Scientist.
# 6.	The data Scientist team help to implement the model and make a prediction based on the dataset.
# 7.	The software team helps to deploy the model on the production side and update the version of the project.
# 8.	The QA Engineer is responsible for testing the product, finds the defects in the project, and report it to the developer team to fix those defects and follow the software testing life cycle.
# 9.	The Technical Support Team is responsible for provide the service 24/7 to the users and solve their product related problems.
#
#
# **7. Budget**
#
# The below table gives the details of the project budget
#
# ![alt text](https://drive.google.com/uc?id=1F0tNFJr748_5MWyifChBUFp6h1sr2e9P)
#
# **Bibliography**
#
# Ionut, T. (2015). Data mining in healthcare: decision making and precision . Database Systems Journal vol , 33-40.
#
# Ogundele, I. e. (2018). A Review on Data Mining in Healthcare. International Journal of Advanced Research in Computer Engineering & Technology , 698-704.
#
# Wang, Y. e. (2017). A Novel Consistent Random Forest Framework. IEEE TRANSACTIONS ON NEURAL NETWORKS AND LEARNING SYSTEMS , 1-14.
